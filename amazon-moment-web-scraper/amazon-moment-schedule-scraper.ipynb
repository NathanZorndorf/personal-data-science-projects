# %%
from bs4 import BeautifulSoup
import requests

# %%
username = 'zornatha'
password = 'HvK45CdRL&Lw+*$'

# %%
login_url = 'na.amzheimdall.com'
login_url_long = 'https://na.amzheimdall.com/login?clientId=WorkforceManagementGoa-prod-na&nonce=1%3Aq4BXQFn7wV79nZrbLd2s1JlCDZsrdNR9aViHZ7JW8MA&redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate'

# %%
# username form
# <form id="passwordForm" 
# method="post" 
# action="/login?sif_profile=gi_profile_1&amp;clientId=WorkforceManagementGoa-prod-na&amp;nonce=1:q4BXQFn7wV79nZrbLd2s1JlCDZsrdNR9aViHZ7JW8MA&amp;state=&amp;redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate" 
# class="a-spacing-micro">
action = "/login?sif_profile=gi_profile_1&amp;clientId=WorkforceManagementGoa-prod-na&amp;nonce=1:q4BXQFn7wV79nZrbLd2s1JlCDZsrdNR9aViHZ7JW8MA&amp;state=&amp;redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate"

# username HTML
# <input type="text" required="" id="usernameInputField" name="username" class="a-input-text a-spacing-base">

# "Next" button
# <input class="a-button-input" type="submit" value="Login" aria-labelledby="submitButton-announce">

# %%
# Start the session
session = requests.Session()

# Create the payload
payload = {'username':username}

# create post url 
url = login_url_long + action # not sure about this...

# Post the payload to the site to log in
s = session.post(url, data=payload)

# %%
print(s.status_code)
# Out:
# 200

# %%
password_url = s.url
print(password_url)
# Out:
# https://na.amzheimdall.com/login?clientId=WorkforceManagementGoa-prod-na&nonce=1%3Aq4BXQFn7wV79nZrbLd2s1JlCDZsrdNR9aViHZ7JW8MA&redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate%2Flogin%3Fsif_profile%3Dgi_profile_1&userName=zornatha&ownerName=amazon

# %%
# retrieved manually from web page
password_url = "https://na.amzheimdall.com/login?clientId=WorkforceManagementGoa-prod-na&nonce=1%3AO7NmBWDPkZ942HtYtqvjqMd5EaCoio7jKiG-9LQ5V8Q&redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate&state=&userName=zornatha&ownerName=amazon"
print(password_url)
# Out:
# https://na.amzheimdall.com/login?clientId=WorkforceManagementGoa-prod-na&nonce=1%3AO7NmBWDPkZ942HtYtqvjqMd5EaCoio7jKiG-9LQ5V8Q&redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate&state=&userName=zornatha&ownerName=amazon

# %%
password_url = "https://na.amzheimdall.com/login?sif_profile=gi_profile_1&clientId=WorkforceManagementGoa-prod-na&nonce=1:R8xnLnfTgRTJ2NNehpkKo2_H6nLZQtF__RfnQ2RGgck&state=&redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate"

# %%
# password form
# <form id="passwordForm" 
# method="post" 
# action="/login?sif_profile=gi_profile_1&amp;clientId=WorkforceManagementGoa-prod-na&amp;nonce=1:q4BXQFn7wV79nZrbLd2s1JlCDZsrdNR9aViHZ7JW8MA&amp;state=&amp;redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate" 
# class="a-spacing-micro">
action = "/login?sif_profile=gi_profile_1&amp;clientId=WorkforceManagementGoa-prod-na&amp;nonce=1:q4BXQFn7wV79nZrbLd2s1JlCDZsrdNR9aViHZ7JW8MA&amp;state=&amp;redirect_uri=https%3A%2F%2Fna.amazonmoment.com%2Fgoa%2Fwfm%2Fauthenticate"

# password box
# <input type="password" required="" id="passwordInputField" name="password" class="a-input-text a-spacing-base">

# %%
# create password payload
payload = {'password':password}

# create form submission url
# url = password_url + action
url = password_url

# Post the payload to the site to log in
s = session.post(url, data=payload)

# %%
print(s.status_code)
# Out:
# 200

# %%
print(s.text)
# Out:
# <!doctype html><html lang="en-US" class="a-no-js" data-19ax5a9jf="dingo">
#     <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
#         <link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|012LjolmrML.css,017DsKjNQJL.css,01NL3TVKoYL.css,01zAp95w-aL.css,41EWOOlBJ9L.css,11PIM2x8KnL.css,01ElnPiDxWL.css,11QxHU4QYaL.css,01Sp8sB1HiL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,01evdoiemkL.css,01K+Ps1DeEL.css,314djKvMsUL.css,01W6EiNzKkL.css,51AZ-Jz5kmL.css,11UGC+GXOPL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,019SHZnt8RL.css,114ZQmBOqHL.css,21bWcRJYNIL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,01SHjPML6tL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,310Imb6LqFL.css,01piEq-AdwL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21mOLw+nYYL.css,01giMEP+djL.css_.css?AUIClients/AmazonUI#us.not-trident.282109-T1.263677-T1.278290-T2" />
# ...

# %%
# sample calendar HTML with open shifts 
soup = BeautifulSoup('''<body data-new-gr-c-s-check-loaded="14.984.0" data-gr-ext-installed="">

<associate ng-version="4.1.0"><div class="container p-0">     <div class="alert alert-info alert-dismissible" id="redirectionBanner" hidden="">         <a aria-label="close" class="close" data-dismiss="alert" href="#">×</a>         You have been redirected to Amazon Moment from CSSM Mobile,Click on CSSM to go back.     </div>     <div class="alert alert-info alert-dismissible" id="notificationBanner">         <a aria-label="close" class="close" data-dismiss="alert" href="#">×</a>         NOTE: If you are experiencing any of the following symptoms (fever, cough, or difficulty breathing), please contact a health care provider and stay home until you have been fever-free for at least 72 hours without the use of fever-reducing medicine. Cancel your shifts in Moment and contact your manager, HR or ERC for any questions. Stay Safe!     </div>     <message><!----><div class="fixed-top container p-0">     <!----> </div></message>     <nav class="navbar navbar-light bg-faded rounded navbar-toggleable-md">         <button aria-controls="containerNavbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler navbar-toggler-right" data-target="#containerNavbar" data-toggle="collapse" type="button">             <span class="navbar-toggler-icon"></span>         </button>         <a class="navbar-brand" href="#">Amazon Moment</a>         <button class="btn btn-link" type="button" hidden="">CSSM Mobile</button>         <!----><div class="collapse navbar-collapse" id="containerNavbar">             <ul class="navbar-nav mr-auto">                 <li class="nav-item">                     <a class="nav-link active" href="/goa/wfm/associate/schedule" routerlink="/schedule" routerlinkactive="active">Your schedule</a>                 </li>                 <li class="nav-item">                     <a class="nav-link" href="/goa/wfm/associate/adjustments" routerlink="/adjustments" routerlinkactive="active">Adjust your schedule</a>                 </li>                 <li class="nav-item">                     <!---->                 </li>             </ul>             <ul class="navbar-nav">                 <li class="nav-item">                     <a class="nav-link" href="/goa/wfm/associate/account" routerlink="/account" routerlinkactive="active">Your account</a>                 </li>                 <li class="nav-item" hidden="">                     <a class="nav-link" data-target="#feedbackModal" data-toggle="modal" style="cursor: pointer;">Feedback</a>                 </li>                 <li class="nav-item dropdown" hidden="">                     <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="helpDropdown">Help</a>                     <div aria-labelledby="helpDropdown" class="dropdown-menu">                         <a class="dropdown-item" href="https://w.amazon.com/index.php/CS_Schedule_Manager/FAQ" target="_blank">                             FAQ                         </a>                         <a class="dropdown-item" href="https://heroes.corp.amazon.com/tags/CSTech" target="_blank">                             Community Q&amp;A                         </a>                         <a class="dropdown-item" data-target="#supportModal" data-toggle="modal">                             Support                         </a>                     </div>                 </li>                 <li class="nav-item">                     <a class="nav-link" href="/goa/wfm/admin">Admin</a>                 </li>                 <li class="nav-item">                     <a class="nav-link" href="/goa/wfm/logout">Logout</a>                 </li>             </ul>         </div>     </nav>           <div aria-hidden="true" aria-labelledby="supportModalTitle" class="modal fade" id="supportModal" role="dialog" tabindex="-1">         <div class="modal-dialog" role="document">             <div class="modal-content">                 <div class="modal-header">                     <h5 class="modal-title" id="supportModalTitle">Support</h5>                     <label aria-hidden="true" class="sr-only" id="supportClose">Close</label>                     <button aria-labelledby="supportClose" class="close" data-dismiss="modal" type="button">                         <span aria-hidden="true">×</span>                     </button>                 </div>                 <div class="modal-body">                     <ul>                         <li>Did you check the <a target="_blank" href="https://w.amazon.com/index.php/CS_Schedule_Manager/FAQ">FAQ</a>?</li>                         <li>Did you check the <a target="_blank" href="https://heroes.corp.amazon.com/tags/CSTech">community Q&amp;A</a>?</li>                         <li>Did you search for <a target="_blank" href="https://tt.amazon.com/search?category=&amp;assigned_group=CS+Workforce+Management%3BRTWO%3BCS+Tech+CPO&amp;status=Assigned%3BResearching%3BWork+In+Progress%3BPending">existing tickets</a>?</li>                     </ul>                 </div>                 <div class="modal-footer">                     <button class="btn btn-primary" data-dismiss="modal" type="button">                         Yes, I completed the above steps                     </button>                 </div>             </div>         </div>     </div>      <div class="modal fade" id="feedbackModal">         <user-feedback><div class="modal-dialog">     <div class="modal-content">         <div class="modal-header">             <h5 class="modal-title" id="feedbackModalTitle">Feedback</h5>             <button class="close" data-dismiss="modal" id="closeFeedbackModalButton" type="button">                 <span>×</span>             </button>         </div>         <div class="modal-body">             <textarea class="form-control ng-untouched ng-pristine ng-valid" id="userFeedbackInput" rows="3" placeholder="Enter feedback here..."></textarea>         </div>         <div class="modal-footer">             <div class="loader small" hidden=""></div>             <button class="btn btn-primary" type="button" disabled="">                 Submit</button>         </div>     </div> </div></user-feedback>     </div>      <router-outlet></router-outlet><view-userschedule ng-version="4.1.0"><div class="card mt-1">     <b class="card-header">Your schedule</b>     <div class="card-block">     	<message><!----><div class="fixed-top container p-0">     <!----> </div></message>         <div class="row user-schedule-selector-row">             <div class="col-xs-6">                 <week-selector> <button class="btn btn-secondary fc-prev-button fc-button" type="button">Prev</button> <button class="btn btn-primary fc-today-button fc-button" type="button">Now</button> <button class="btn btn-secondary fc-prev-button fc-button" type="button">Next</button></week-selector>             </div>             <div class="col-xs-4">                 <datetime-selector><div>     <input class="form-control ng-untouched ng-pristine ng-invalid datetime-selector" type="text"> </div></datetime-selector>             </div>             <div class="col-xs-2">                 <!---->             </div>         </div>         <div class="card mt-4">             <div class="card-block">                 <div class="form-group">                     Schedule Filter:                     <select class="custom-select ng-untouched ng-pristine ng-valid">                         <!----><option value="Extra Time">Extratime</option><option value="Voluntary Time-off">Voluntary Time-off</option><option value="None">None</option>                     </select>                 </div>                 <div class="form-group">                     Workgroups:                     <select class="custom-select ng-valid ng-dirty ng-touched">                         <!----><option value="Copperfield_WholeFoodsMarket-CAS10396">Copperfield_WholeFoodsMarket-CAS10396</option><option value="Copperfield_WholeFoodsMarket-OCN10432">Copperfield_WholeFoodsMarket-OCN10432</option>                     </select>                 </div>                 <div class="form-group">                     <button class="btn btn-primary" type="button">Display</button>                 </div>                 <div class="form-group alert alert-info">                     <div>                         <b><u>Extra Time available this week</u></b>                     </div>                     <div hidden="">                         <b><u>Voluntary Time-off available this week</u></b>                     </div>                     <!----><div>                         <!----><div>                             <u>Copperfield_WholeFoodsMarket-OCN10432</u>                             <ul class="list-inline">                                 <!----><li>                                     2020-11-15                                  </li>                             </ul>                         </div>                     </div>                 </div>             </div>         </div>          <basecard> <message><!----><div class="fixed-top container p-0">     <!----> </div></message> <div>     <!----><div>         <fieldset>             <div base-card-body="">                 <calendar><calendar-event-detail><!----></calendar-event-detail> <div class="mx-auto fc fc-unthemed fc-ltr" id="calendar"><div class="fc-toolbar fc-header-toolbar"><div class="fc-left"></div><div class="fc-right"></div><div class="fc-center"></div><div class="fc-clear"></div></div><div class="fc-view-container" style=""><div class="fc-view fc-agendaWeek-view fc-agenda-view" style=""><table><thead class="fc-head"><tr><td class="fc-head-container fc-widget-header"><div class="fc-row fc-widget-header"><table><thead><tr><th class="fc-axis fc-widget-header" style="width: 50px;"></th><th class="fc-day-header fc-widget-header fc-sun fc-today" data-date="2020-11-15"><span>Sun 11/15</span></th><th class="fc-day-header fc-widget-header fc-mon fc-future" data-date="2020-11-16"><span>Mon 11/16</span></th><th class="fc-day-header fc-widget-header fc-tue fc-future" data-date="2020-11-17"><span>Tue 11/17</span></th><th class="fc-day-header fc-widget-header fc-wed fc-future" data-date="2020-11-18"><span>Wed 11/18</span></th><th class="fc-day-header fc-widget-header fc-thu fc-future" data-date="2020-11-19"><span>Thu 11/19</span></th><th class="fc-day-header fc-widget-header fc-fri fc-future" data-date="2020-11-20"><span>Fri 11/20</span></th><th class="fc-day-header fc-widget-header fc-sat fc-future" data-date="2020-11-21"><span>Sat 11/21</span></th></tr></thead></table></div></td></tr></thead><tbody class="fc-body"><tr><td class="fc-widget-content"><div class="fc-day-grid fc-unselectable"><div class="fc-row fc-week fc-widget-content"><div class="fc-bg"><table><tbody><tr><td class="fc-axis fc-widget-content" style="width: 50px;"><span>all-day</span></td><td class="fc-day fc-widget-content fc-sun fc-today fc-state-highlight" data-date="2020-11-15"></td><td class="fc-day fc-widget-content fc-mon fc-future" data-date="2020-11-16"></td><td class="fc-day fc-widget-content fc-tue fc-future" data-date="2020-11-17"></td><td class="fc-day fc-widget-content fc-wed fc-future" data-date="2020-11-18"></td><td class="fc-day fc-widget-content fc-thu fc-future" data-date="2020-11-19"></td><td class="fc-day fc-widget-content fc-fri fc-future" data-date="2020-11-20"></td><td class="fc-day fc-widget-content fc-sat fc-future" data-date="2020-11-21"></td></tr></tbody></table></div><div class="fc-content-skeleton"><table><tbody><tr><td class="fc-axis" style="width:50px"></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td></tr></tbody></table></div></div></div><hr class="fc-divider fc-widget-header"><div class="fc-scroller fc-time-grid-container" style="overflow: hidden scroll; height: 991px;"><div class="fc-time-grid fc-unselectable"><div class="fc-bg"><table><tbody><tr><td class="fc-axis fc-widget-content" style="width: 50px;"></td><td class="fc-day fc-widget-content fc-sun fc-today fc-state-highlight" data-date="2020-11-15"></td><td class="fc-day fc-widget-content fc-mon fc-future" data-date="2020-11-16"></td><td class="fc-day fc-widget-content fc-tue fc-future" data-date="2020-11-17"></td><td class="fc-day fc-widget-content fc-wed fc-future" data-date="2020-11-18"></td><td class="fc-day fc-widget-content fc-thu fc-future" data-date="2020-11-19"></td><td class="fc-day fc-widget-content fc-fri fc-future" data-date="2020-11-20"></td><td class="fc-day fc-widget-content fc-sat fc-future" data-date="2020-11-21"></td></tr></tbody></table></div><div class="fc-slats"><table><tbody><tr data-time="00:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>0:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="00:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="01:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>1:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="01:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="02:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>2:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="02:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="03:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>3:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="03:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="04:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>4:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="04:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="05:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>5:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="05:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="06:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>6:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="06:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="07:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>7:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="07:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="08:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>8:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="08:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="09:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>9:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="09:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="10:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>10:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="10:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="11:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>11:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="11:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="12:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>12:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="12:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="13:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>13:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="13:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="14:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>14:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="14:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="15:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>15:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="15:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="16:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>16:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="16:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="17:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>17:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="17:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="18:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>18:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="18:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="19:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>19:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="19:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="20:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>20:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="20:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="21:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>21:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="21:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="22:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>22:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="22:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr><tr data-time="23:00:00"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"><span>23:00</span></td><td class="fc-widget-content"></td></tr><tr data-time="23:30:00" class="fc-minor"><td class="fc-axis fc-time fc-widget-content" style="width: 50px;"></td><td class="fc-widget-content"></td></tr></tbody></table></div><div class="fc-content-skeleton"><table><tbody><tr><td class="fc-axis" style="width: 50px;"></td><td><div class="fc-content-col"><div class="fc-event-container fc-helper-container"></div><div class="fc-event-container"><a class="fc-time-grid-event fc-v-event fc-event fc-start fc-end posting" style="top: 199px; bottom: -424px; z-index: 1; left: 0%; right: 0%; margin-right: 20px;"><div class="fc-content"><div class="fc-title">ET Apply</div></div><div class="fc-bg"></div></a><a class="fc-time-grid-event fc-v-event fc-event fc-start fc-end posting" style="top: 199px; bottom: -411.5px; z-index: 2; left: 50%; right: 0%;"><div class="fc-content"><div class="fc-title">ET Apply</div></div><div class="fc-bg"></div></a></div><div class="fc-highlight-container"></div><div class="fc-bgevent-container"></div><div class="fc-business-container"></div></div></td><td><div class="fc-content-col"><div class="fc-event-container fc-helper-container"></div><div class="fc-event-container"></div><div class="fc-highlight-container"></div><div class="fc-bgevent-container"></div><div class="fc-business-container"></div></div></td><td><div class="fc-content-col"><div class="fc-event-container fc-helper-container"></div><div class="fc-event-container"></div><div class="fc-highlight-container"></div><div class="fc-bgevent-container"></div><div class="fc-business-container"></div></div></td><td><div class="fc-content-col"><div class="fc-event-container fc-helper-container"></div><div class="fc-event-container"></div><div class="fc-highlight-container"></div><div class="fc-bgevent-container"></div><div class="fc-business-container"></div></div></td><td><div class="fc-content-col"><div class="fc-event-container fc-helper-container"></div><div class="fc-event-container"></div><div class="fc-highlight-container"></div><div class="fc-bgevent-container"></div><div class="fc-business-container"></div></div></td><td><div class="fc-content-col"><div class="fc-event-container fc-helper-container"></div><div class="fc-event-container"></div><div class="fc-highlight-container"></div><div class="fc-bgevent-container"></div><div class="fc-business-container"></div></div></td><td><div class="fc-content-col"><div class="fc-event-container fc-helper-container"></div><div class="fc-event-container"></div><div class="fc-highlight-container"></div><div class="fc-bgevent-container"></div><div class="fc-business-container"></div></div></td></tr></tbody></table></div><hr class="fc-divider fc-widget-header" style="display: none;"></div></div></td></tr></tbody></table></div></div></div></calendar>             </div>         </fieldset>     </div>     <!----> </div> </basecard>     </div> </div></view-userschedule> </div></associate>



<script src="/goa/wfm/static/vendors.min.js"></script>
<script src="/goa/wfm/static/wfm.associate.v9.js"></script><div class="daterangepicker ltr single auto-apply opensright"><div class="ranges"></div><div class="drp-calendar left single" style="display: block;"><div class="calendar-time" style="display: none;"></div><div class="calendar-table"></div></div><div class="drp-calendar right" style="display: none;"><div class="calendar-time" style="display: none;"></div><div class="calendar-table"></div></div><div class="drp-buttons"><span class="drp-selected">2020-11-15 - 2020-11-15</span><button class="cancelBtn btn btn-sm btn-default" type="button">Cancel</button><button class="applyBtn btn btn-sm btn-primary" disabled="disabled" type="button">Apply</button> </div></div>

    <script src="https://cdnjs.cloudflare.com/ajax/libs/tether/1.4.0/js/tether.min.js" integrity="sha384-DztdAPBWPRXSA/3eYEEUWrWCy7G5KFbe8fFjk5JAIxUYHKkDx6Qin1DkWx51bBrb" crossorigin="anonymous"></script>
    <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0-alpha.6/js/bootstrap.min.js" integrity="sha384-vBWWzlZJ8ea9aCX4pEW3rVHjgjt7zpkNpZk+02D9phzyeVkE+jo0ieGizqPLForn" crossorigin="anonymous"></script>
    <script src="https://gitcdn.github.io/bootstrap-toggle/2.2.2/js/bootstrap-toggle.min.js"></script>

</body>''', 'html.parser')
