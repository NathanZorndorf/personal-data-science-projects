# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.express as px

# %%
# grab hospital capacity data
# https://data.sfgov.org/COVID-19/COVID-19-Hospital-Capacity/rh24-ebzg
url = "https://data.sfgov.org/resource/rh24-ebzg.json"
df = pd.read_json(url)

# %%
df = df.sort_values('date', ascending=False)
df.head(10)
# Out:
#                    hospital       date              bed_type  \
# 335  All SF Acute Hospitals 2020-09-01            Acute Care
# 334  All SF Acute Hospitals 2020-09-01            Acute Care
# 333  All SF Acute Hospitals 2020-09-01        Intensive Care
# 332  All SF Acute Hospitals 2020-09-01        Intensive Care
# 331  All SF Acute Hospitals 2020-09-01        Intensive Care
# 330  All SF Acute Hospitals 2020-09-01      Acute Care Surge
# 329  All SF Acute Hospitals 2020-09-01            Acute Care
# 328  All SF Acute Hospitals 2020-09-01  Intensive Care Surge
# 320  All SF Acute Hospitals 2020-08-31  Intensive Care Surge
# 325  All SF Acute Hospitals 2020-08-31        Intensive Care
#
#                                status  count
# 335                    Other Patients   1111
# 334  COVID-19 (Confirmed & Suspected)     55
# 333                    Other Patients    161
# 332  COVID-19 (Confirmed & Suspected)     21
# 331                         Available    104
# 330                         Available    442
# 329                         Available    326
# 328                         Available    309
# 320                         Available    309
# 325                    Other Patients    148

# %%
url = "https://data.sfgov.org/resource/nfpa-mg4g.json"
df = pd.read_json(url)
df.head(10)
# Out:
#   specimen_collection_date  tests  pos       pct  neg  indeterminate  \
# 0  2020-02-28T00:00:00.000      2    0  0.000000    2              0
# 1  2020-03-01T00:00:00.000      2    0  0.000000    2              0
# 2  2020-03-02T00:00:00.000      2    0  0.000000    2              0
# 3  2020-03-03T00:00:00.000      8    2  0.250000    6              0
# 4  2020-03-04T00:00:00.000     12    0  0.000000   12              0
# 5  2020-03-05T00:00:00.000     23    6  0.260870   17              0
# 6  2020-03-06T00:00:00.000     21    1  0.047619   20              0
# 7  2020-03-07T00:00:00.000     23    7  0.304348   16              0
# 8  2020-03-08T00:00:00.000     12    3  0.250000    9              0
# 9  2020-03-09T00:00:00.000     63    4  0.063492   59              0
#
#       last_updated_at
# 0 2020-12-03 14:15:00
# 1 2020-12-03 14:15:00
# 2 2020-12-03 14:15:00
# 3 2020-12-03 14:15:00
# 4 2020-12-03 14:15:00
# 5 2020-12-03 14:15:00
# 6 2020-12-03 14:15:00
# 7 2020-12-03 14:15:00
# 8 2020-12-03 14:15:00
# 9 2020-12-03 14:15:00
